# %% [markdown]
# # PE2 광소자 분석 (VpiL / IL / ER)
# 계산은 `src/wafer_analyzer.py`, 이 노트북은 결과만 화면에 띄운다.  Run -> Run All Cells.

# %%
# %matplotlib inline
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), 'src'))
import wafer_analyzer as wa

FOLDER = 'dat/HY202103'
WAFERS = ['D07', 'D08', 'D23', 'D24']
data = wa.load(FOLDER, WAFERS)
length_map = wa.build_length_map(FOLDER, WAFERS)

# %% [markdown]
# ## 고를 수 있는 웨이퍼 / 날짜 / 다이 확인

# %%
print('웨이퍼:', wa.list_wafers(data))
print('D07 날짜:', wa.list_dates(data, 'D07'))
print('D07 20190715 다이:', wa.list_dies(data, 'D07', '20190715'))

# %% [markdown]
# ## 분석할 대상 선택 (아래 값만 바꾸면 모든 그래프가 그 대상으로 바뀜)

# %%
WAFER = 'D07'
DATE  = '20190715'
BAND  = 'LMZC'        # LMZC(C-band) 또는 LMZO(O-band)
DIE   = (-4, -1)      # (열, 행) - VpiL 곡선 볼 다이

# %% [markdown]
# ## VpiL
# 선택한 다이의 곡선 + 웨이퍼 전체 분포(맵 / Center vs Edge)

# %%
wa.plot_die_vpil(data, length_map, WAFER, DATE, BAND, *DIE)

# %%
wa.plot_wafer_map(data, length_map, WAFER, DATE, BAND, 'vpil')

# %%
wa.plot_box(data, length_map, WAFER, DATE, BAND, 'vpil')

# %% [markdown]
# ## IL (삽입손실)
# 웨이퍼 위치별 분포 + Center vs Edge

# %%
wa.plot_wafer_map(data, length_map, WAFER, DATE, BAND, 'il')

# %%
wa.plot_box(data, length_map, WAFER, DATE, BAND, 'il')

# %% [markdown]
# ## ER (소광비)
# 웨이퍼 위치별 분포 + Center vs Edge

# %%
wa.plot_wafer_map(data, length_map, WAFER, DATE, BAND, 'er')

# %%
wa.plot_box(data, length_map, WAFER, DATE, BAND, 'er')

# %% [markdown]
# ## (선택) 드롭다운으로 다이 골라 VpiL 곡선 보기

# %%
wa.interactive(data, length_map, 'vpil')

# %% [markdown]
# ## 분석 코멘트
# - VpiL 공간 분포:
# - IL / ER 경향:
# - 위상으로 본 V_pi:
